// %% [markdown]
// # Sección XIII
// # Writing Documentation

// %% [markdown]
// There are several things to know about documentation:
//
//     - ● godoc.org
//         standard library and third party package documentation
//     - ● golang.org
//         standard library documentation
//     - ● go doc
//         command to read documentation at the command line
//     - ● godoc
//         command to read documentation at the command line
//         also can run a local server showing documentation

// %% [markdown]
// ## go doc
//     It allows us to read documentation at the command line at the terminal
//
//     > go doc
//
//     > go help doc
//
//     > go doc -cmd cmd/doc : Show package docs and exported symbols within the doc command.
//
//
// So go doc accept zero one or two arguments. If you give it zero arguments, it's going to give you documentation for whatever package you are using when you run it.
//
//
//     > go doc package_name/Code
//
//     > go doc Name_function
//
//     > go doc package.Name_function

// %% [markdown]
// ![go_doc.png](attachment:go_doc.png)

// %% [markdown]
// ## godoc
//
// Extracts and generates documentation for Go programs.
//
//
// https://go.dev/doc/cmd
//
//
// With godoc you can have all the documentation in your machine
//
//         > godoc -http :8080  (It is closed with ctrl C)
//
//         Then you enter the url: localhost:8080
//
//             And then, you have all documentation locally. Including the standar library and ANY OF THE CODE THAT'S ON MY COMPUTER
//
//
//
//
// go doc gives a higer level overview
//
//     - go doc fmt
//     - godoc fmt

// %% [markdown]
//     It has two modes then:
//
//         - without -http flag
//             - Has the -src flag (Comments)
//         - with -http flag: runs as a web server and presents the documentation as a web page

// %% [markdown]
// Si queremos, por ejemplo que el Paquete esté en godoc, lo que se hace es copiar el link de github en el buscador y buscarlo. Luego aparecerá, lo guardará godoc.org

// %% [markdown]
// ## Wrinting Doc
//
// Es muy facil!!!
// Nuestra documentación serán todos nuestros comentarios!!
//
// - https://go.dev/blog/godoc
//
//
// Thinks to take in mint:
//
//     - It can be used in : a type, variable, constant, function, or package.
//     - write a comment directly preceding its declaration, with no intervening blank      line.
//     - begin with the name of the element. It's a convention to use the name of whatever you're documenting as the first thing in the sentence.
//
//         - write complete sentences. With a final dot/periods at the end

// %% [markdown]
// Example by: https://cs.opensource.google/go/go/+/refs/tags/go1.20.5:src/errors/errors.go;l=61

// %%
// New returns an error that formats as the given text.
// Each call to New returns a distinct error value even if the text is identical.
func New(text string) error {
	return &errorString{text}
}

// errorString is a trivial implementation of error.
type errorString struct {
	s string
}
// Out:
// repl.go:5:9: incompatible types in assignment: error = *main.errorString
// 	reason: *main.errorString does not implement error: missing method func (error).Error() string

// %% [markdown]
// You can create a file called doc.go.
//
// When you have a lot to say you star with /* */
//
// Sin enters!!!!

// %%
/*
haoolsd
sdfs
sdf

sdf
*/      
package fmt

// %% [markdown]
// If it is in a git link.
// you can:
//
//         - godoc path_github with_or_without_funtion

// %% [markdown]
// ## Notas Ejercicio 1
//
// En terminal, tratemos de exportar el paquete

// %%
import "Dog"

// %%
import "fmt"

// %%
import "Dog"
func main(){
    a:=Dog.Year(3)
    fmt.Println(a)
}
main()
// Out:
// repl.go:3:8: undefined "Dog" in Dog.Year <*ast.SelectorExpr>
